# %%
1.Write a python program which searches all the product under a particular product from www.amazon.in. The 
product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for 
guitars.

# %%
import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
import requests
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
import time

# %%
#Getting into Amazon website
driver=webdriver.Chrome()
driver.maximize_window()
driver.get("https://www.amazon.in/")

# %%
user_input = input('Enter the product that we want to search : ')
# Out:
# Enter the product that we want to search : iphone

# %%
SearchText=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/div[2]/form/div/div/input')
SearchText.send_keys(user_input)
SearchText.submit()

# %%
2.In the above question, now scrape the following details of each product listed in first 3 pages of your search 
results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then 
scrape all the products available under that product name. Details to be scraped are: "Brand 
Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and 
“Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
#Scraping Product URL
product_urls = []   
start=0
end=3
for i in range(start,end):    
    url = driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url:
        product_urls.append(i.get_attribute("href"))
    next_btn = driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    next_btn.click()
    time.sleep(3)

# %%
len(product_urls)
# Out:
# 55

# %%
Brand =[]
Name =[]
Price =[]
Return_Exchange =[]
Expected_Delivery=[]
Availability =[]


#loop for every iphone in the list

for i in product_urls:
    driver.get(i)
    time.sleep(4)
    
    #Scraping BrandName
    try:
        brand=driver.find_element(By.XPATH,'/html/body/div[4]/div/div[3]/div[11]/div[48]/div/table/tbody/tr[1]')
        Brand.append(brand.text)
    except NoSuchElementException:
        Brand.append('-')
        
    #Scraping Name:   
    try:
        name=driver.find_element(By.XPATH,'/html/body/div[4]/div/div[3]/div[11]/div[3]/div/h1/span')
        Name.append(name.text)
    except NoSuchElementException:
        Name.append('-')
        
    #Scraping Price:   
    try:
        price=driver.find_element(By.XPATH,'/html/body/div[4]/div/div[3]/div[11]/div[17]/div/div/div[4]/div[1]/span[3]/span[2]/span[2]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')
        
   #Scraping Return/Exchange     
    try:
        exchange=driver.find_element(By.XPATH,'/html/body/div[4]/div/div[3]/div[8]/div[8]/div/div[1]/div/div[1]/div/div/div[1]/div/div[1]/h5/div[2]/span/span')
        Return_Exchange.append(exchange.text)
    except NoSuchElementException:
        Return_Exchange.append('-')
        
    #Scraping Expected Delivery   
    try:
        delivery=driver.find_element(By.XPATH,'/html/body/div[4]/div/div[3]/div[8]/div[8]/div/div[1]/div/div[1]/div/div/div[2]/div/div[2]/div/form/div/div/div[3]/div[10]/div[1]/div/div/div[1]/span/span')
        Expected_Delivery.append(delivery.text)
    except NoSuchElementException:
        Expected_Delivery.append('-')
        
        
    #Scraping Availability   
    try:
        availability=driver.find_element(By.XPATH,'/html/body/div[4]/div/div[3]/div[8]/div[8]/div/div[1]/div/div[1]/div/div/div[2]/div/div[2]/div/form/div/div/div[5]/div/div[1]/span')
        Availability.append(availability.text)
    except NoSuchElementException:
        Availability.append('-')

# %%
print(len(Brand),len(Name),len(Price),len(Return_Exchange),len(Expected_Delivery),len(Availability))
# Out:
# 55 55 55 55 55 55

# %%
import pandas as pd
AmazonData=pd.DataFrame({"Brand Name":Brand,"Name of the Product":Name,"Price":Price,"Return/Exchange":Return_Exchange,
                         "Expected Delivey":Expected_Delivery,"Availability":Availability,"Product URL":product_urls})
AmazonData
# Out:
#      Brand Name                                Name of the Product     Price  \
# 0   Brand Apple                    Apple iPhone 13 (128GB) - Green    48,799
# 1   Brand Apple                Apple iPhone 13 (128GB) - Starlight         -
# 2   Brand Apple                     Apple iPhone 13 (128GB) - Blue    48,799
# 3   Brand Apple                     Apple iPhone 13 (128GB) - Pink    48,799
# 4   Brand Apple                 Apple iPhone 13 (128GB) - Midnight    48,999
# 5   Brand Apple                    Apple iPhone 14 (128 GB) - Blue    62,800
# 6   Brand Apple                Apple iPhone 13 (256GB) - Starlight    57,499
# 7   Brand Apple                    Apple iPhone 15 (128 GB) - Blue    71,499
# 8   Brand Apple               Apple iPhone 14 (128 GB) - Starlight    62,800
# 9   Brand Apple                 Apple iPhone 13 (256GB) - Midnight    57,999
# 10            -                                                  -         -
# ...

# %%
3.. Write a python program to access the search bar and search button on images.google.com and scrape 10 
images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’

# %%
#Getting into google image website
driver=webdriver.Chrome()
driver.maximize_window()
driver.get("https://images.google.com/")

# %%
#Search for Machine Learning

search=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea')
search.send_keys("Machine Learning")

# %%
#click on Search
MLSearch=driver.find_element(By.CLASS_NAME,"zgAlFc")
MLSearch.click()
time.sleep(3)

# %%
#Scroll down
for _ in range(20):
    driver.execute_script("window.scrollBy(0,500)")

#Scraping images
image_urls=[]
urls = []
images=driver.find_elements(By.XPATH,'//img[@class="YQ4gaf"]')
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:5] == 'https'):
            image_urls.append(source)
            
for i in image_urls[:10]:
        urls.append(i)      
            
#Downloading images
for i in range(len(urls)):
    if i >10:
         breakBy.XPATH,
    print("Downloading {0} of {1} images" .format(i,10))
    response = requests.get(image_urls[i])
    file = open(r"C:\Users\RajiBaskar\OneDrive\Pictures"+str(i)+".jpg","wb")
    file.write(response.content)

# %%
5.Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
driver=webdriver.Chrome()
driver.maximize_window()
driver.get("https://www.google.com/maps/")

# %%
#Entering location
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[1]/form/input")
search.send_keys("Chennai")

# %%
#Click on search
clickonLocation=driver.find_element(By.XPATH,'//span[@class="google-symbols"]')
clickonLocation.click()

# %%
#Scraping Latitude and Longitude
import re
try:
    url_str = driver.current_url
    print("URL Extracted: ", url_str)
    lat_long = re.findall(r'@(.*)data',url_str)
    if len(lat_long):
        lat_lng_list = lat_long[0].split(",")
        if len(lat_lng_list)>=2:
            latitude = lat_lng_list[0]
            longitude = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(latitude, longitude))
except Exception as e:
        print("Error: ", str(e))
# Out:
# URL Extracted:  https://www.google.com/maps/place/Chennai,+Tamil+Nadu/@13.0473169,79.8793406,10z/data=!3m1!4b1!4m6!3m5!1s0x3a5265ea4f7d3361:0x6e61a70b6863d433!8m2!3d13.0843007!4d80.2704622!16zL20vMGM4dGs?entry=ttu
# Latitude = 13.0473169, Longitude = 79.8793406

# %%
6. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
#getting into digits page
driver=webdriver.Chrome()
driver.maximize_window()
driver.get("https://www.digit.in/")

# %%
#Click on Top 10
Top10Link=driver.find_element(By.XPATH,'//*[@id="menu-item-290390"]/a')
Top10Link.click()

# %%
#Click on Best AI link

AI = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div[2]/div[1]/div[4]/div[2]/p/a')
AI.click()

# %%
Lap_url=[]

urls=driver.find_elements(By.XPATH,'//h3[@class="font130 mt0 mb10 mobilesblockdisplay "]/a')
for i in urls:
    Lap_url.append(i.get_attribute('href'))

# %%
Laptop_Name=[]
Display=[]
Processor=[]
Operating_Sys=[]


for i in Lap_url:
    driver.get(i)
    time.sleep(4)


    try:
        laptop_name = driver.find_element(By.XPATH,'/html/body/div[2]/div[3]/div[1]/div/div/div/div/div[2]/div[1]/div[1]/h1')
        Laptop_Name.append(laptop_name.text)
    except NoSuchElementException:
        Laptop_Name.append('--')
    
    try:
        os = driver.find_element(By.XPATH,'/html/body/div[2]/div[3]/div[1]/div/div/div/div/div[2]/div[1]/div[4]/div[3]/div/div/ul/li[1]/div/p[2]/strong')
        Operating_Sys.append(os.text)
    except NoSuchElementException:
        Operating_Sys.append('--')
    
    try:
        display= driver.find_element(By.XPATH,'/html/body/div[2]/div[3]/div[1]/div/div/div/div/div[2]/div[1]/div[4]/div[3]/div/div/ul/li[2]/div/p[2]/strong')
        Display.append(display.text)
    except NoSuchElementException:
        Display.append('--')
    
    try:
        proc = driver.find_element(By.XPATH,'/html/body/div[2]/div[3]/div[1]/div/div/div/div/div[2]/div[1]/div[4]/div[3]/div/div/ul/li[4]/div/p[2]/strong')
        Processor.append(proc.text)
    except NoSuchElementException:
        Processor.append('--')

# %%
print(len(Laptop_Name),len(Operating_Sys),len(display),len(Processor))
# Out:
# 8 8 1 8

# %%
Laptop_Name
# Out:
# ['MSI Prestige 16 AI Evo B1M',
#  'Asus ROG Zephyrus G14 GA402XZ-N2019WS',
#  'Acer Predator Triton Neo 16',
#  'ASUS Zenbook 14 OLED (UX3405)\nSpecs Score\n8.4/10',
#  'HP Spectre x360 16-aa0664TX',
#  'Lenovo IdeaPad Pro 5 Core Ultra',
#  'Acer Nitro V 16 (ANV16-41)',
#  'Acer Swift Go 14 SFG14-72T']

# %%
7. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: 
“Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver=webdriver.Chrome()
driver.maximize_window()
driver.get("https://www.forbes.com/billionaires/")

# %%
#Empty list
Rank=[]
Name=[]
Networth=[]
Age=[]
Citizenship=[]
Source=[]
Industry=[]

#Scraping Rank
rank = driver.find_elements(By.XPATH,'//div[@class="Table_rank__X4MKf"]')
for i in rank:
    Rank.append(i.text)

#Scraping Name

name = driver.find_elements(By.XPATH,'//div[@class="Table_personName__Bus2E"]')
for i in name:
    Name.append(i.text)

#Scraping Networth
networth = driver.find_elements(By.XPATH,'//div[@class="Table_finalWorth__UZA6k"]')
for i in networth:
    Networth.append(i.text)
    
#Scraping Age
age = driver.find_elements(By.XPATH,'//div[@class="Table_tableRow__lF_cY Table_expanded__0lLQ6"]/div[4]')
for i in age:
    Age.append(i.text)   

#Scraping Citizenship
citizen = driver.find_elements(By.XPATH,'//div[@class="Table_tableRow__lF_cY Table_expanded__0lLQ6"]/div[5]')
for i in networth:
    Citizenship.append(i.text)  
    
#Scraping Source
source = driver.find_elements(By.XPATH,'//div[@class="Table_tableRow__lF_cY Table_expanded__0lLQ6"]/div[6]')
for i in source:
    Source.append(i.text) 
    
#Scraping Industry
Indus = driver.find_elements(By.XPATH,'//div[@class="Table_tableRow__lF_cY Table_expanded__0lLQ6"]/div[7]')
for i in Indus:
    Industry.append(i.text)

# %%
print(len(Rank),len(Name),len(Networth),len(Age),len(Citizenship),len(Source),len(Industry))
# Out:
# 400 200 200 1 200 1 1

# %%
8. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted 
from any YouTube Video.

# %%
#Getting into youtube page

driver=webdriver.Chrome()
driver.maximize_window()
driver.get("https://www.youtube.com/")

# %%
#Search for song

search=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/div/ytd-masthead/div[4]/div[2]/ytd-searchbox/form/div[1]/div[1]/input')
search.send_keys("rowdy baby")
time.sleep(3)

# %%
#Click on search bar

searchClick=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/div/ytd-masthead/div[4]/div[2]/ytd-searchbox/button')
searchClick.click()
time.sleep(3)

# %%
#Click on video
video = driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-search/div[1]/ytd-two-column-search-results-renderer/div/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-video-renderer[1]/div[1]/div/div[1]/div/h3/a/yt-formatted-string')
video.click()
time.sleep(3)

# %%
#Scroll down windows
for _ in range(500):     
    driver.execute_script("window.scrollBy(0,10000)")

    
Comments=[]
Comment_time=[]
Time=[]
Comments_upvote=[]
Vote=[]

#Scraping comments

cmt=driver.find_elements(By.XPATH,'//div[@class="style-scope ytd-expander"]')
for i in cmt:
    if i.text is None:
        Comments.append('--')
    else:
        Comments.append(i.text)
time.sleep(5)
    


#Scraping Comment time
tm = driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-view-model"]/a')
for i in tm:
    Time.append(i.text)
    
for i in range(0,len(Time),2):
    Comment_time.append(Time[i])
time.sleep(4)



# scrape the comment likes
vote = driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-engagement-bar"]')
for i in vote:
    Vote.append(i.text)
    
for i in range(1,len(Vote),2):
    Comments_upvote.append(Vote[i])

# %% [markdown]
# 9.Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall
# reviews, privates from price, dorms from price, facilities and property description.

# %%
driver=webdriver.Chrome()
driver.maximize_window()
driver.get("https://www.hostelworld.com/")
time.sleep(3)

# %%
#Entering location as London
location=driver.find_element(By.CLASS_NAME,"native-input")
location.send_keys("London")
time.sleep(3)

# %%
#Click on London,England
Click_on_London=driver.find_element(By.XPATH,'/html/body/div[3]/div/div[2]/main/header/div/div[2]/div[1]/div[1]/div/div[1]/div[2]/div/ul/li[2]/button/div[2]/div[1]')
Click_on_London.click()
time.sleep(3)

# %%
#Click on Let's go
Letsgo=driver.find_element(By.XPATH,'//html/body/div[3]/div/div[2]/main/header/div/div[2]/div[1]/div[1]/div/div[5]/button[2]/span')
Letsgo.click()
time.sleep(3)

# %%
#Empty List

Hostel_name=[]
Distance=[]
Ratings=[]
TotalReview=[]
OverallReview=[]
Price=[]


for i in range(0,3):
    
    #Scraping Hostel Name
    try:
        name = driver.find_elements(By.XPATH,'//div[@class="property-name"]')
        for i in name:
            Hostel_name.append(i.text)
    except NoSuchElementException:
        Hostel_name.append('-')  
        
        
    #Scraping Dist
    try:
        Dist = driver.find_elements(By.XPATH,'//span[@class="distance-description"]')
        for i in Dist:
            Distance.append(i.text)
    except NoSuchElementException:
        Distance.append('-') 
   
    #Scraping Hostel Ratings
        
    try:
        rat = driver.find_elements(By.XPATH,'//span[@class="number"]')
        for i in rat:
            Ratings.append(i.text)
    except NoSuchElementException:
        Ratings.append('-')  

    #Scraping Overall Review
        
    try:
        Orev = driver.find_elements(By.XPATH,'//span[@class="keyword"]')
        for i in Orev:
            OverallReview.append(i.text)
    except NoSuchElementException:
        OverallReview.append('-')    
        
        
    #Scraping Overall Review
    try:
        Trev = driver.find_elements(By.XPATH,'//span[@class="left-margin"]')
        for i in Trev:
            TotalReview.append(i.text)
    except NoSuchElementException:
        TotalReview.append('-')   
        
        
    #Scraping Price

    try:
        pr = driver.find_elements(By.XPATH,'//div[@class="accommodation-price single-row"]')
        for i in pr:
            Price.append(i.text)
    except NoSuchElementException:
        Price.append('-')

# %%
print(len(Hostel_name),len(Distance),len(Ratings),len(OverallReview),len(TotalReview),len(Price))
# Out:
# 96 90 96 96 90 108

# %%
#getting hostel urls
hurls=[]
for i in range(0,3):
    hrul=driver.find_elements(By.XPATH,'//a[@class="property-card-container horizontal"]')
    for i in hrul:
        hurls.append(i.get_attribute("href"))

# %%
len(hurls)
# Out:
# 90

# %%
Price=[]
facilities=[]
property_description=[]

for i in hurls:
    driver.get(i)
    time.sleep(3)
    
 
 #Scraping facilities

    try:
        fac=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/section/div[16]/div/ul/li[1]/ul/li[1]')
        facilities.append(fac.text)
    except NoSuchElementException:
        facilities.append('-')


#Scraping property_description
  
    try:
        desc=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/section/div[10]/div/div[2]/div[6]/div/div[2]')
        property_description.append(desc.text)   
    except NoSuchElementException:
        property_description.append('--')

# %%
print(len(facilities),len(property_description))
# Out:
# 90 90

# %%
import pandas as pd
HostelData=pd.DataFrame({"Hostel Name":Hostel_name[:90],"Distance from city center":Distance,"Ratings":Ratings[:90],"Overall Review":OverallReview[:90],
                         "Total Review":TotalReview,"Price":Price[:90],"Facility":facilities,"Property Des":property_description})
HostelData
# Out:
#                             Hostel Name Distance from city center Ratings  \
# 0         Palmers Lodge - Swiss Cottage  - 3.6km from city centre     8.7
# 1              St Christopher's Village  - 6.5km from city centre     7.5
# 2           Wombat's City Hostel London  - 0.7km from city centre     9.3
# 3         Palmers Lodge - Swiss Cottage  - 6.1km from city centre     8.7
# 4                       Onefam Waterloo  - 5.4km from city centre     9.5
# ..                                  ...                       ...     ...
# 85           Smart Hyde Park Inn Hostel  - 7.6km from city centre     7.6
# 86                       Astor Victoria  - 5.5km from city centre     7.2
# 87  Hostelle - women only hostel London  - 4.3km from city centre     8.5
# 88           Kabannas London St Pancras  - 3.3km from city centre     8.3
# 89                     Astor Kensington  - 7.5km from city centre     7.9
#
#    Overall Review Total Review       Price Facility Property Des
# ...

# %%
4.Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com
and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand 
Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera” “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the 
details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
#Getting into FlipKart page
driver=webdriver.Chrome()
driver.maximize_window()
driver.get("https://www.flipkart.com/")

# %%
#Search for Oneplus Nord
searchBar=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input')
searchBar.send_keys('Oneplus Nord')

search=driver.find_element(By.CLASS_NAME,"_2iLD__")
search.click()

# %%
#Scraping 1st page url
URL=[]

urls=driver.find_elements(By.XPATH,'//a[@class="CGtC98"]')
for i in urls:
    URL.append(i.get_attribute('href'))

# %%
len(URL)
# Out:
# 24

# %%
Brand_Name=[]
Name=[]
RAM=[]
ROM=[]
Rear_Camera=[]
Display=[]
Battery_Capacity=[]
Price=[]



for i in URL:
    driver.get(i)
    time.sleep(4)
    
    #Scraping Brand Name
    try:
        brand = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[4]/div/div[2]/div/div[1]/table/tbody/tr[3]/td[2]/ul/li')
        Brand_Name.append(brand.text)
    except NoSuchElementException:
        Brand_Name.append('-') 
    
    #Scraping SmartPhone Name
    try:
        name = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div[1]/h1/span')
        Name.append(name.text)
    except NoSuchElementException:
        Name.append('-') 
        
    #Scraping RAM
    try:
        ram = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[5]/div/div[2]/div[1]/div/ul/li[2]')
        RAM.append(ram.text)
    except NoSuchElementException:
        RAM.append('-') 
        
    #Scraping ROM
    try:
        rom = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[5]/div/div[2]/div[1]/div/ul/li[2]/a')
        ROM.append(rom.text)
    except NoSuchElementException:
        ROM.append('-') 
        
        
    #Scraping Camera
    try:
        rcamera = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[1]/div/div[2]/ul/li[3]')
        Rear_Camera.append(rcamera.text)
    except NoSuchElementException:
        Rear_Camera.append('-') 
        
    #Scraping display size
    try:
        disp = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[1]/div/div[2]/ul/li[2]')
        Display.append(disp.text)
    except NoSuchElementException:
        Display.append('-') 
       
    #Scraping Battery Capacity
    try:
        batt = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[1]/div/div[2]/ul/li[4]')
        Battery_Capacity.append(batt.text)
    except NoSuchElementException:
        Battery_Capacity.append('-') 
        
        
    #Scraping Price
    try:
        Prc = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div[4]/div[1]/div/div[1]')
        Price.append(Prc.text)
    except NoSuchElementException:
        Price.append('-')

# %%
print(len(Brand_Name),len(Name),len(RAM),len(ROM),len(Rear_Camera),len(Display),len(Battery_Capacity),len(Price))
# Out:
# 24 24 24 24 24 24 24 24

# %%
import pandas as pd
flipKartData=pd.DataFrame({"Brand Name":Brand_Name,"Name":Name,"RAM":RAM,"ROM":ROM,"Camera":Rear_Camera,"Display_Size":Display,
                          "Battery Capacity":Battery_Capacity,"Price":Price})
flipKartData
# Out:
#            Brand Name                                               Name  \
# 0   Nord CE 3 Lite 5G  OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB...
# 1   Nord CE 3 Lite 5G  OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128...
# 2   Nord CE 3 Lite 5G  OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...
# 3   Nord CE 3 Lite 5G  OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB...
# 4           Nord 3 5G  OnePlus Nord 3 5G (Tempest Gray, 128 GB)  (8 G...
# 5                   -  OnePlus Nord 3 5G (Tempest Gray, 256 GB)  (16 ...
# 6           Nord 3 5G  OnePlus Nord 3 5G (Misty Green, 128 GB)  (8 GB...
# 7                   -  OnePlus Nord 3 5G (Misty Green, 256 GB)  (16 G...
# 8                   -  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...
# 9   Nord CE 2 Lite 5G  OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB) ...
# 10           Nord CE4  OnePlus Nord CE4 (Dark Chrome, 256 GB)  (8 GB ...
# 11           Nord CE4  OnePlus Nord CE4 (Celadon Marble, 256 GB)  (8 ...
# ...
